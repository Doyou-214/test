# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.set_style('whitegrid')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

def sinplot(flip=1): #自定义一个函数
    x = np.linspace(0,14,100) #0-14取100个点

    for i in range(1,7):
        plt.plot(x,np.sin(x + i *0.5) * (7 - i) * flip)
#plt.show()

#sinplot()


with sns.axes_style("darkgrid"): #with里面的用一种背景风格
    plt.subplot(211)
    sinplot()
plt.subplot(212)
sinplot(-1)
plt.show()

# %%
sns.palplot(sns.light_palette('green'))

# %%
import numpy as np
data  = np.random.normal(size = (20,12)) + np.arange(12)
sns.boxplot(data = data,palette=current_palette)
plt.show()

# %%
from scipy import stats
x=  np.random.normal(size=100)
sns.distplot(x,bins=20,kde=False,fit=stats.gamma)
plt.show()
# Out:
# E:\Jupyter\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.jointplot(x = "x",y = "y",data = data)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-a42b08ade8cb> in <module>()
# ----> 1 sns.jointplot(x = "x",y = "y",data = data)
#
# E:\Jupyter\lib\site-packages\seaborn\axisgrid.py in jointplot(x, y, data, kind, stat_func, color, size, ratio, space, dropna, xlim, ylim, joint_kws, marginal_kws, annot_kws, **kwargs)
#    2239     grid = JointGrid(x, y, data, dropna=dropna,
#    2240                      size=size, ratio=ratio, space=space,
# -> 2241                      xlim=xlim, ylim=ylim)
#    2242
#    2243     # Plot the data using the grid
#
# E:\Jupyter\lib\site-packages\seaborn\axisgrid.py in __init__(self, x, y, data, size, ratio, space, dropna, xlim, ylim)
#    1675         # Possibly extract the variables from a DataFrame
#    1676         if data is not None:
# -> 1677             x = data.get(x, x)
#    1678             y = data.get(y, y)
#    1679
#
# AttributeError: 'numpy.ndarray' object has no attribute 'get'

# %%
x = np.random.normal(size=10)
y = np.random.normal(size=10)
sns.regplot(x,y)
